# %% [markdown]
# # Scrape Mangareader

# %% [markdown]
# ## Set-up for a single page
# ### Selenium to access JS components

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from PIL import Image
from io import BytesIO
import requests
import time

# %%
# Find the number of chapters in the manga "Vagabond Colored Edition"
# setup webdriver
driver = webdriver.Chrome()

# navigate to the webpage
driver.get('https://mangareader.to/read/dorohedoro-57/en/chapter-1')

# Find the button with the text "Reject All" and click it using JavaScript
button = driver.find_element(By.XPATH, "//span[text()='Reject All']")
driver.execute_script("arguments[0].click();", button)

# Find the element with the class "dropdown-item mode-item" and data-value "horizontal" and click it using JavaScript
element = driver.find_element(By.XPATH, "//a[@class='dropdown-item mode-item' and @data-value='horizontal']")
driver.execute_script("arguments[0].click();", element)

# make the driver wait for 5 seconds
time.sleep(5)

# use BeautifulSoup to parse the HTML
soup = BeautifulSoup(driver.page_source, 'html.parser')

# find the first li element with the class "item reading-item chapter-item"
li_element = soup.find('li', class_='item reading-item chapter-item')

# extract the data-number attribute and convert it to an integer
data_number = float(li_element['data-number'])

# %%
import os
# Loop through all the chapters
for chapter in range(1, int(data_number) + 1):
    driver.get(f"https://mangareader.to/read/dorohedoro-57/en/chapter-{chapter}")

    # Update the soup object with the new page content
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Find all div elements with class "ds-image shuffled loaded" and "ds-image shuffled"
    divs = soup.find_all('div', class_=['ds-image shuffled loaded', 'ds-image shuffled'])

    # If no divs were found, try finding divs with class "ds-image loaded"
    if not divs:
        divs = soup.find_all('div', class_='ds-image loaded')

    # Check if any data URLs were found
    if not divs:
        print(f"Chapter {chapter}: No images found")
        continue  # Skip to the next chapter

    # Extract data-url from each div and store in a list
    data_urls = [div.get('data-url') for div in divs]

    # Download images
    images = []
    for url in data_urls:
        try:
            response = requests.get(url)
            img = Image.open(BytesIO(response.content))
            images.append(img)
        except requests.exceptions.RequestException as e:
            print(f"Chapter {chapter}: Error downloading image: {e}")

    # Check if any images were downloaded
    if not images:
        print(f"Chapter {chapter}: Failed to download any images")
        continue  # Skip to the next chapter

    # Convert images to JPEG format
    images = [img.convert('RGB') for img in images]

    os.makedirs(f"Chapter_{chapter}", exist_ok=True)

    # Save images in the chapter subfolder  
    for i, img in enumerate(images):
        img.save(f"Chapter_{chapter}/Image_{i+1}.jpeg")

    print(f"Chapter {chapter}: Downloaded {len(images)} images")
# Out:
# Chapter 1: Downloaded 24 images
# Chapter 2: Downloaded 26 images
# Chapter 3: Downloaded 24 images
# Chapter 4: Downloaded 24 images
# Chapter 5: Downloaded 24 images
# Chapter 6: Downloaded 24 images
# Chapter 7: Downloaded 34 images
# Chapter 8: Downloaded 28 images
# Chapter 9: Downloaded 28 images
# Chapter 10: Downloaded 28 images
# Chapter 11: Downloaded 28 images
# Chapter 12: Downloaded 28 images
# Chapter 13: Downloaded 28 images
# Chapter 14: Downloaded 23 images
# Chapter 15: Downloaded 24 images
# Chapter 16: Downloaded 24 images
# Chapter 17: Downloaded 24 images
# Chapter 18: Downloaded 24 images
# Chapter 19: Downloaded 24 images
# Chapter 20: Downloaded 24 images
# Chapter 21: Downloaded 25 images
# Chapter 22: Downloaded 24 images
# Chapter 23: Downloaded 24 images
# Chapter 24: Downloaded 24 images
# Chapter 25: Downloaded 24 images
# Chapter 26: Downloaded 23 images
# Chapter 27: Downloaded 24 images
# Chapter 28: Downloaded 24 images
# Chapter 29: Downloaded 24 images
# Chapter 30: Downloaded 24 images
# Chapter 31: Downloaded 25 images
# Chapter 32: Downloaded 23 images
# Chapter 33: Downloaded 24 images
# Chapter 34: Downloaded 24 images
# Chapter 35: Downloaded 24 images
# Chapter 36: Downloaded 24 images
# Chapter 37: Downloaded 25 images
# Chapter 38: Downloaded 24 images
# Chapter 39: Downloaded 24 images
# Chapter 40: Downloaded 24 images
# Chapter 41: Downloaded 24 images
# Chapter 42: Downloaded 24 images
# Chapter 43: Downloaded 24 images
# Chapter 44: Downloaded 26 images
# Chapter 45: Downloaded 28 images
# Chapter 46: Downloaded 23 images
# Chapter 47: Downloaded 25 images
# Chapter 48: Downloaded 23 images
# Chapter 49: Downloaded 24 images
# Chapter 50: Downloaded 30 images
# Chapter 51: Downloaded 24 images
# Chapter 52: Downloaded 24 images
# Chapter 53: Downloaded 23 images
# Chapter 54: Downloaded 24 images
# Chapter 55: Downloaded 24 images
# Chapter 56: Downloaded 24 images
# Chapter 57: Downloaded 24 images
# Chapter 58: Downloaded 24 images
# Chapter 59: Downloaded 24 images
# Chapter 60: Downloaded 31 images
# Chapter 61: Downloaded 24 images
# Chapter 62: Downloaded 24 images
# Chapter 63: Downloaded 23 images
# Chapter 64: Downloaded 24 images
# Chapter 65: Downloaded 24 images
# Chapter 66: Downloaded 26 images
# Chapter 67: Downloaded 31 images
# Chapter 68: Downloaded 23 images
# Chapter 69: Downloaded 24 images
# Chapter 70: Downloaded 24 images
# Chapter 71: Downloaded 24 images
# Chapter 72: Downloaded 31 images
# Chapter 73: Downloaded 24 images
# Chapter 74: Downloaded 24 images
# Chapter 75: Downloaded 23 images
# Chapter 76: Downloaded 24 images
# Chapter 77: Downloaded 24 images
# Chapter 78: Downloaded 31 images
# Chapter 79: Downloaded 34 images
# Chapter 80: Downloaded 24 images
# Chapter 81: Downloaded 26 images
# Chapter 82: Downloaded 26 images
# Chapter 83: Downloaded 26 images
# Chapter 84: Downloaded 32 images
# Chapter 85: Downloaded 31 images
# Chapter 86: Downloaded 24 images
# Chapter 87: Downloaded 23 images
# Chapter 88: Downloaded 23 images
# Chapter 89: Downloaded 24 images
# Chapter 90: Downloaded 24 images
# Chapter 91: Downloaded 23 images
# Chapter 92: Downloaded 26 images
# Chapter 93: Downloaded 25 images
# Chapter 94: Downloaded 24 images
# Chapter 95: Downloaded 27 images
# Chapter 96: Downloaded 24 images
# Chapter 97: Downloaded 24 images
# Chapter 98: Downloaded 24 images
# Chapter 99: Downloaded 24 images
# Chapter 100: Downloaded 23 images
# Chapter 101: Downloaded 24 images
# Chapter 102: Downloaded 24 images
# Chapter 103: Downloaded 23 images
# Chapter 104: Downloaded 24 images
# Chapter 105: Downloaded 23 images
# Chapter 106: Downloaded 23 images
# Chapter 107: Downloaded 24 images
# Chapter 108: Downloaded 24 images
# Chapter 109: Downloaded 25 images
# Chapter 110: Downloaded 23 images
# Chapter 111: Downloaded 23 images
# Chapter 112: Downloaded 24 images
# Chapter 113: Downloaded 24 images
# Chapter 114: Downloaded 23 images
# Chapter 115: Downloaded 26 images
# Chapter 116: Downloaded 24 images
# Chapter 117: Downloaded 24 images
# Chapter 118: Downloaded 23 images
# Chapter 119: Downloaded 24 images
# Chapter 120: Downloaded 24 images
# Chapter 121: Downloaded 24 images
# Chapter 122: Downloaded 24 images
# Chapter 123: Downloaded 24 images
# Chapter 124: Downloaded 24 images
# Chapter 125: Downloaded 24 images
# Chapter 126: Downloaded 24 images
# Chapter 127: Downloaded 24 images
# Chapter 128: Downloaded 23 images
# Chapter 129: Downloaded 23 images
# Chapter 130: Downloaded 24 images
# Chapter 131: Downloaded 23 images
# Chapter 132: Downloaded 24 images
# Chapter 133: Downloaded 24 images
# Chapter 134: Downloaded 24 images
# Chapter 135: Downloaded 24 images
# Chapter 136: Downloaded 24 images
# Chapter 137: Downloaded 24 images
# Chapter 138: Downloaded 24 images
# Chapter 139: Downloaded 24 images
# Chapter 140: Downloaded 24 images
# Chapter 141: Downloaded 24 images
# Chapter 142: Downloaded 23 images
# Chapter 143: Downloaded 24 images
# Chapter 144: Downloaded 23 images
# Chapter 145: Downloaded 23 images
# Chapter 146: Downloaded 29 images
# Chapter 147: Downloaded 35 images
# Chapter 148: Downloaded 28 images
# Chapter 149: Downloaded 27 images
# Chapter 150: Downloaded 32 images
# Chapter 151: Downloaded 24 images
# Chapter 152: Downloaded 31 images
# Chapter 153: Downloaded 31 images
# Chapter 154: Downloaded 31 images
# Chapter 155: Downloaded 50 images
# Chapter 156: Downloaded 23 images
# Chapter 157: Downloaded 26 images
# Chapter 158: Downloaded 24 images
# Chapter 159: Downloaded 23 images
# Chapter 160: Downloaded 23 images
# Chapter 161: Downloaded 24 images
# Chapter 162: Downloaded 24 images
# Chapter 163: Downloaded 23 images
# Chapter 164: Downloaded 32 images
# Chapter 165: Downloaded 31 images
# Chapter 166: Downloaded 33 images
# Chapter 167: Downloaded 31 images

# %% [markdown]
# ## Find bonus chapters

# %%
valid_urls = []  # Create an empty list to store valid URLs

for chapter in range(1, int(data_number) + 2):

    # Check for a decimal chapter
    bonus_chapter = chapter + 0.5
    bonus_url = f"https://mangareader.to/read/dorohedoro-57/en/chapter-{bonus_chapter}"

    response = requests.get(bonus_url)

    if response.status_code == 200:
        valid_urls.append(bonus_url)
